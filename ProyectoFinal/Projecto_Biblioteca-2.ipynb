# %%
inventario = {
  "libro": {
    1: {"titulo": "El Principito", "autor": "Antoine de Saint-Exupéry", "cantidad": 5, "prestados": 0},
    2: {"titulo": "Cien años de soledad", "autor": "Gabriel García Márquez", "cantidad": 3, "prestados": 0},
    3: {"titulo": "1984", "autor": "George Orwell", "cantidad": 2, "prestados": 0},
    4: {"titulo": "Don Quijote de la Mancha", "autor": "Miguel de Cervantes", "cantidad": 4, "prestados": 0},
    5: {"titulo": "Harry Potter y la piedra filosofal", "autor": "J.K. Rowling", "cantidad": 6, "prestados": 0},
    6: {"titulo": "Matar a un ruiseñor", "autor": "Harper Lee", "cantidad": 3, "prestados": 0},
    7: {"titulo": "Los juegos del hambre", "autor": "Suzanne Collins", "cantidad": 2, "prestados": 0},
    8: {"titulo": "El alquimista", "autor": "Paulo Coelho", "cantidad": 4, "prestados": 0},
    9: {"titulo": "El señor de los anillos", "autor": "J.R.R. Tolkien", "cantidad": 5, "prestados": 0},
    10: {"titulo": "El gran Gatsby", "autor": "F. Scott Fitzgerald", "cantidad": 3, "prestados": 0}
},
  "revista":{
    11: {"titulo": "Revista de Ciencia", "autor": "Science", "cantidad": 10, "prestados": 0},
    12: {"titulo": "Revista de Tecnología", "autor": "Tech", "cantidad": 8, "prestados": 0},
    13: {"titulo": "Revista de Historia", "autor": "History", "cantidad": 6, "prestados": 0},
    14: {"titulo": "Revista de Arte", "autor": "Art", "cantidad": 4, "prestados": 0},
    15: {"titulo": "Revista de Economía", "autor": "Economics", "cantidad": 7, "prestados": 0},
    16: {"titulo": "Revista de Deporte", "autor": "Sports", "cantidad": 9, "prestados": 0},
    17: {"titulo": "Revista de Viajes", "autor": "Travel", "cantidad": 5, "prestados": 0},
    18: {"titulo": "Revista de Food", "autor": "Food", "cantidad": 3, "prestados": 0},
    19: {"titulo": "Revista de Ciencia Ficción", "autor": "Sci-Fi", "cantidad": 6, "prestados": 0},
    20: {"titulo": "Revista de Ciencia Política", "autor": "Politics", "cantidad": 4, "prestados": 0}
}
}
# ---------------- FUNCIONES ----------------

'''def agregar_material(tipo, titulo, autor, cantidad):
    nuevo_material = {
        "titulo": titulo,
        "autor": autor,
        "cantidad": cantidad,
        "prestados": 0
    }
    inventario[tipo].append(nuevo_material)
    print(f"\n✅ {tipo.title()} agregada con éxito: '{titulo}'\n")'''


def mostrar_inventario():
    print("\n📚 Inventario de la Biblioteca Pública de Popayán:\n")
    for tipo in inventario:
        print(f"🔸 {tipo.title()}:")
        if not inventario[tipo]:
            print("   (No hay registros)")
        for i, item in enumerate(inventario[tipo].values(), start=1):
            disponibles = item["cantidad"] - item["prestados"]
            print(f"  {i}. Título: {item['titulo']} | Autor: {item['autor']} | Disponibles: {disponibles} / {item['cantidad']}")
    print()

'''def mostrar_inventario():
    print("=== INVENTARIO DE LIBROS ===")
    for id_libro, libro in inventario["libros"].items():
        disponibles = libro["cantidad"] - libro["prestados"]
        print(f"{id_libro}. {libro['titulo']} - {libro['autor']} | Total: {libro['cantidad']}, Prestados: {libro['prestados']}, Disponibles: {disponibles}")

    print("\n=== INVENTARIO DE REVISTAS ===")
    for id_revista, revista in inventario["revistas"].items():
        disponibles = revista["cantidad"] - revista["prestados"]
        print(f"{id_revista}. {revista['titulo']} - {revista['autor']} | Total: {revista['cantidad']}, Prestados: {revista['prestados']}, Disponibles: {disponibles}")
'''
def prestar_material(tipo, titulo):
    for item in inventario[tipo].values():
        if item["titulo"].lower() == titulo.lower():
            disponibles = item["cantidad"] - item["prestados"]
            if disponibles > 0:
                item["prestados"] += 1
                print(f"\n✅ Préstamo registrado para '{titulo}'.\n")
                return
            else:
                print(f"\n⚠️ No hay ejemplares disponibles de '{titulo}'.\n")
                return
    print(f"\n❌ {tipo.title()} no encontrado.\n")


def devolver_material(tipo, titulo):
    for item in inventario[tipo].values():
        if item["titulo"].lower() == titulo.lower():
            if item["prestados"] > 0:
                item["prestados"] -= 1
                print(f"\n✅ Devolución registrada para '{titulo}'.\n")
                return
            else:
                print(f"\n⚠️ No hay ejemplares prestados de '{titulo}'.\n")
                return
    print(f"\n❌ {tipo.title()} no encontrado.\n")


def mostrar_menu():
    print("""
======= Sistema de Gestión - Biblioteca Pública de Popayán =======


3. Mostrar inventario
4. Prestar libro
5. Prestar revista
6. Devolver libro
7. Devolver revista
0. Salir
""")


# ---------------- PROGRAMA PRINCIPAL ----------------

while True:
    mostrar_menu()
    opcion = input("Seleccione una opción: ")

    '''if opcion == "1":
        titulo = input("Título del libro: ")
        autor = input("Autor del libro: ")
        cantidad = int(input("Cantidad de ejemplares: "))
        agregar_material("libro", titulo, autor, cantidad)

    elif opcion == "2":
        titulo = input("Título de la revista: ")
        autor = input("Autor/editorial: ")
        cantidad = int(input("Cantidad de ejemplares: "))
        agregar_material("revista", titulo, autor, cantidad)'''

    if opcion == "3":
        mostrar_inventario()

    elif opcion == "4":
        titulo = input("Título del libro a prestar: ")
        prestar_material("libro", titulo)

    elif opcion == "5":
        titulo = input("Título de la revista a prestar: ")
        prestar_material("revista", titulo)

    elif opcion == "6":
        titulo = input("Título del libro a devolver: ")
        devolver_material("libro", titulo)

    elif opcion == "7":
        titulo = input("Título de la revista a devolver: ")
        devolver_material("revista", titulo)

    elif opcion == "0":
        print("\n👋 Gracias por usar el sistema. ¡Hasta pronto!\n")
        break

    else:
        print("\n❌ Opción inválida. Intente nuevamente.\n")
# Out:
# ======= Sistema de Gestión - Biblioteca Pública de Popayán =======
#
#
# 3. Mostrar inventario
# 4. Prestar libro
# 5. Prestar revista
# 6. Devolver libro
# 7. Devolver revista
# 0. Salir
#
# Seleccione una opción: 6
# Título del libro a devolver: el principiot
#
# ❌ Libro no encontrado.
#
#
# ======= Sistema de Gestión - Biblioteca Pública de Popayán =======
#
#
# 3. Mostrar inventario
# 4. Prestar libro
# 5. Prestar revista
# 6. Devolver libro
# 7. Devolver revista
# 0. Salir
#
# Seleccione una opción: 6
# Título del libro a devolver: el principito
#
# ⚠️ No hay ejemplares prestados de 'el principito'.
#
#
# ======= Sistema de Gestión - Biblioteca Pública de Popayán =======
#
#
# 3. Mostrar inventario
# 4. Prestar libro
# 5. Prestar revista
# 6. Devolver libro
# 7. Devolver revista
# 0. Salir
#
# Seleccione una opción: 3
#
# 📚 Inventario de la Biblioteca Pública de Popayán:
#
# 🔸 Libro:
#   1. Título: El Principito | Autor: Antoine de Saint-Exupéry | Disponibles: 5 / 5
#   2. Título: Cien años de soledad | Autor: Gabriel García Márquez | Disponibles: 3 / 3
#   3. Título: 1984 | Autor: George Orwell | Disponibles: 2 / 2
#   4. Título: Don Quijote de la Mancha | Autor: Miguel de Cervantes | Disponibles: 4 / 4
#   5. Título: Harry Potter y la piedra filosofal | Autor: J.K. Rowling | Disponibles: 6 / 6
#   6. Título: Matar a un ruiseñor | Autor: Harper Lee | Disponibles: 3 / 3
#   7. Título: Los juegos del hambre | Autor: Suzanne Collins | Disponibles: 2 / 2
#   8. Título: El alquimista | Autor: Paulo Coelho | Disponibles: 4 / 4
#   9. Título: El señor de los anillos | Autor: J.R.R. Tolkien | Disponibles: 5 / 5
#   10. Título: El gran Gatsby | Autor: F. Scott Fitzgerald | Disponibles: 3 / 3
# 🔸 Revista:
#   1. Título: Revista de Ciencia | Autor: Science | Disponibles: 10 / 10
#   2. Título: Revista de Tecnología | Autor: Tech | Disponibles: 8 / 8
#   3. Título: Revista de Historia | Autor: History | Disponibles: 6 / 6
#   4. Título: Revista de Arte | Autor: Art | Disponibles: 4 / 4
#   5. Título: Revista de Economía | Autor: Economics | Disponibles: 7 / 7
#   6. Título: Revista de Deporte | Autor: Sports | Disponibles: 9 / 9
#   7. Título: Revista de Viajes | Autor: Travel | Disponibles: 5 / 5
#   8. Título: Revista de Food | Autor: Food | Disponibles: 3 / 3
#   9. Título: Revista de Ciencia Ficción | Autor: Sci-Fi | Disponibles: 6 / 6
#   10. Título: Revista de Ciencia Política | Autor: Politics | Disponibles: 4 / 4
#
#
# ======= Sistema de Gestión - Biblioteca Pública de Popayán =======
#
#
# 3. Mostrar inventario
# 4. Prestar libro
# 5. Prestar revista
# 6. Devolver libro
# 7. Devolver revista
# 0. Salir
#
# Seleccione una opción: 0
#
# 👋 Gracias por usar el sistema. ¡Hasta pronto!
