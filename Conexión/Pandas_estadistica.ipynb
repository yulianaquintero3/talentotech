# %%
import pandas as pd
lista_nombres = ["Alexander", "Alejandra", "Dario", "Wilson"]
lista_pesos = [69,57,64,80]
lista_alturas = [1.78, 1.6, 1.64, 1.71]
dicc_datos={"nombre":lista_nombres, "peso":lista_pesos, "altura":lista_alturas}
df=pd.DataFrame(dicc_datos)
df
# Out:
#       nombre  peso  altura
# 0  Alexander    69    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    1.64
# 3     Wilson    80    1.71

# %%
import pandas as pd
lista_nombres = ["Alexander", "Alejandra", "Dario", "Wilson", "Camila", "Luis", "Maria", "Julio", "Sofia", "Yuliana" ]
lista_pesos = [49,57,64,80, 55,70,65,90,55,60]
lista_alturas = [1.78, 1.6, 1.64, 1.71,1.5,1.82,1.68,1.88,1.45,1.64]
dicc_datos={"nombre":lista_nombres, "peso":lista_pesos, "altura":lista_alturas}
df=pd.DataFrame(dicc_datos)
df
# Out:
#       nombre  peso  altura
# 0  Alexander    49    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    1.64
# 3     Wilson    80    1.71
# 4     Camila    55    1.50
# 5       Luis    70    1.82
# 6      Maria    65    1.68
# 7      Julio    90    1.88
# 8      Sofia    55    1.45
# 9    Yuliana    60    1.64

# %%
df
# Out:
#       nombre  peso  altura
# 0  Alexander    49    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    1.64
# 3     Wilson    80    1.71
# 4     Camila    55    1.50
# 5       Luis    70    1.82
# 6      Maria    65    1.68
# 7      Julio    90    1.88
# 8      Sofia    55    1.45
# 9    Yuliana    60    1.64

# %%
df
# Out:
#       nombre  peso  altura
# 0  Alexander    49    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    1.64
# 3     Wilson    80    1.71
# 4     Camila    55    1.50
# 5       Luis    70    1.82
# 6      Maria    65    1.68
# 7      Julio    90    1.88
# 8      Sofia    55    1.45
# 9    Yuliana    60    1.64

# %%
df
# Out:
#       nombre  peso  altura
# 0  Alexander    49    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    1.64
# 3     Wilson    80    1.71
# 4     Camila    55    1.50
# 5       Luis    70    1.82
# 6      Maria    65    1.68
# 7      Julio    90    1.88
# 8      Sofia    55    1.45
# 9    Yuliana    60    1.64

# %%
df['imc'] = df['peso'] / (df['altura']**2)
df
# Out:
#       nombre  peso  altura       imc2        imc
# 0  Alexander    49    1.78  15.465219  15.465219
# 1  Alejandra    57    1.60  22.265625  22.265625
# 2      Dario    64    1.64  23.795360  23.795360
# 3     Wilson    80    1.71  27.358845  27.358845
# 4     Camila    55    1.50  24.444444  24.444444
# 5       Luis    70    1.82  21.132713  21.132713
# 6      Maria    65    1.68  23.030045  23.030045
# 7      Julio    90    1.88  25.464011  25.464011
# 8      Sofia    55    1.45  26.159334  26.159334
# 9    Yuliana    60    1.64  22.308150  22.308150

# %%
def categorize_imc(imc):
  if imc < 18.5:
    return 'bajo de peso'
  elif imc < 25:
    return 'peso normal'
  else:
    return 'sobrepeso'

df['categoría'] = df['imc'].apply(categorize_imc)
display(df)
# Out:
#       nombre  peso  altura       imc2        imc     categoría
# 0  Alexander    49    1.78  15.465219  15.465219  bajo de peso
# 1  Alejandra    57    1.60  22.265625  22.265625   peso normal
# 2      Dario    64    1.64  23.795360  23.795360   peso normal
# 3     Wilson    80    1.71  27.358845  27.358845     sobrepeso
# 4     Camila    55    1.50  24.444444  24.444444   peso normal
# 5       Luis    70    1.82  21.132713  21.132713   peso normal
# 6      Maria    65    1.68  23.030045  23.030045   peso normal
# 7      Julio    90    1.88  25.464011  25.464011     sobrepeso
# 8      Sofia    55    1.45  26.159334  26.159334     sobrepeso
# 9    Yuliana    60    1.64  22.308150  22.308150   peso normal

# %%
df = df.drop('imc2', axis=1)
df
# Out:
#       nombre  peso  altura        imc     categoría
# 0  Alexander    49    1.78  15.465219  bajo de peso
# 1  Alejandra    57    1.60  22.265625   peso normal
# 2      Dario    64    1.64  23.795360   peso normal
# 3     Wilson    80    1.71  27.358845     sobrepeso
# 4     Camila    55    1.50  24.444444   peso normal
# 5       Luis    70    1.82  21.132713   peso normal
# 6      Maria    65    1.68  23.030045   peso normal
# 7      Julio    90    1.88  25.464011     sobrepeso
# 8      Sofia    55    1.45  26.159334     sobrepeso
# 9    Yuliana    60    1.64  22.308150   peso normal

# %%
import numpy as np
import random

# Generate data for 90 more people
num_additional_people = 90

# Generate more realistic random names
common_names = ["Maria", "Jose", "Ana", "Luis", "Sofia", "Carlos", "Elena", "David", "Isabella", "Mateo",
                "Valeria", "Andres", "Gabriela", "Diego", "Lucia", "Javier", "Paula", "Miguel", "Andrea",
                "Fernando", "Carmen", "Ricardo", "Silvia", "Manuel", "Diana", "Jorge", "Laura", "Pablo",
                "Natalia", "Roberto", "Patricia", "Sergio", "Monica", "Alejandro", "Cristina", "Francisco",
                "Raquel", "Daniel", "Beatriz", "Adrian", "Sara", "Alberto", "Nuria", "Gonzalo", "Marta",
                "Enrique", "Irene", "Alvaro", "Eva", "Rafael", "Marina", "Alfonso", "Claudia", "Victor",
                "Julia", "Ruben", "Lorena", "Ignacio", "Teresa", "Joaquin", "Angela", "Ramón", "Isabel",
                "Emilio", "Rosa", "Angel", "Susana", "Pedro", "Alicia", "Jesus", "Carolina", "Salvador",
                "Pilar", "Federico", "Mercedes", "Arturo", "Rocio", "Juan", "Esther", "Alfredo", "Ines",
                "Felipe", "Gloria", "Gonzalo", "Victoria", "Oscar", "Soledad", "Adolfo", "Esperanza",
                "Gregorio", "Purificacion", "Cecilia", "Vicente", "Rosario", "Ernesto", "Dolores", "Julian",
                "Milagros"]

additional_nombres = random.choices(common_names, k=num_additional_people)

additional_pesos = np.random.randint(40, 100, num_additional_people)
additional_alturas = np.random.uniform(1.4, 2.0, num_additional_people)

# Create a new DataFrame with the additional data
additional_dicc_datos = {"nombre": additional_nombres, "peso": additional_pesos, "altura": additional_alturas}
additional_df = pd.DataFrame(additional_dicc_datos)

# Concatenate the original DataFrame with the additional DataFrame
df = pd.concat([df.iloc[:10], additional_df], ignore_index=True)


# Recalculate imc and categoria for the combined DataFrame
df['imc'] = df['peso'] / (df['altura']**2)
df['categoría'] = df['imc'].apply(categorize_imc)

display(df)
# Out:
#        nombre  peso    altura        imc     categoría
# 0   Alexander    49  1.780000  15.465219  bajo de peso
# 1   Alejandra    57  1.600000  22.265625   peso normal
# 2       Dario    64  1.640000  23.795360   peso normal
# 3      Wilson    80  1.710000  27.358845     sobrepeso
# 4      Camila    55  1.500000  24.444444   peso normal
# ..        ...   ...       ...        ...           ...
# 95     Julian    91  1.426925  44.692927     sobrepeso
# 96  Alejandro    76  1.929578  20.412157   peso normal
# 97     Rafael    70  1.668116  25.156227     sobrepeso
# 98       Ines    75  1.629898  28.231928     sobrepeso
# 99      Marta    71  1.955639  18.564397   peso normal
#
# [100 rows x 5 columns]

# %%
df.describe()
# Out:
#              peso      altura         imc
# count  100.000000  100.000000  100.000000
# mean    68.010000    1.697277   24.185216
# std     16.216026    0.168253    7.296660
# min     40.000000    1.414389   10.622137
# 25%     55.750000    1.539470   19.244213
# 50%     66.000000    1.682558   23.370064
# 75%     81.000000    1.846799   28.055877
# max     99.000000    1.982977   47.005363

# %%
display(df.describe(include='object'))
# Out:
#           nombre    categoría
# count        100          100
# unique        60            3
# top     Fernando  peso normal
# freq           5           40

# %%
display(df.describe(include='all'))
# Out:
#           nombre        peso      altura         imc    categoría
# count        100  100.000000  100.000000  100.000000          100
# unique        60         NaN         NaN         NaN            3
# top     Fernando         NaN         NaN         NaN  peso normal
# freq           5         NaN         NaN         NaN           40
# mean         NaN   68.010000    1.697277   24.185216          NaN
# std          NaN   16.216026    0.168253    7.296660          NaN
# min          NaN   40.000000    1.414389   10.622137          NaN
# 25%          NaN   55.750000    1.539470   19.244213          NaN
# 50%          NaN   66.000000    1.682558   23.370064          NaN
# 75%          NaN   81.000000    1.846799   28.055877          NaN
# max          NaN   99.000000    1.982977   47.005363          NaN

# %% [markdown]
# # Task
# Explica los pasos para realizar un Análisis Exploratorio de Datos (EDA).

# %% [markdown]
# ## Carga y comprensión inicial de los datos
#
# ### Subtask:
# Cargar los datos en un DataFrame y obtener una visión general de su estructura, tipos de datos, y las primeras filas.

# %% [markdown]
# **Reasoning**:
# Display the first few rows, information, and column names of the DataFrame to get an overview of its structure and content.

# %%
display(df.head())
display(df.info())
display(df.columns)
# Out:
#       nombre  peso  altura        imc     categoría
# 0  Alexander    49    1.78  15.465219  bajo de peso
# 1  Alejandra    57    1.60  22.265625   peso normal
# 2      Dario    64    1.64  23.795360   peso normal
# 3     Wilson    80    1.71  27.358845     sobrepeso
# 4     Camila    55    1.50  24.444444   peso normal
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nombre     100 non-null    object
#  1   peso       100 non-null    int64
#  2   altura     100 non-null    float64
#  3   imc        100 non-null    float64
#  4   categoría  100 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 4.0+ KB
# None
# Index(['nombre', 'peso', 'altura', 'imc', 'categoría'], dtype='object')

# %% [markdown]
# ## Limpieza de datos
#
# ### Subtask:
# Identificar y manejar valores faltantes, duplicados, o inconsistencias.

# %% [markdown]
# **Reasoning**:
# Check for missing values and duplicate rows in the DataFrame.

# %%
print("Missing values per column:")
print(df.isnull().sum())

print("\nNumber of duplicate rows:")
print(df.duplicated().sum())
# Out:
# Missing values per column:
# nombre       0
# peso         0
# altura       0
# imc          0
# categoría    0
# dtype: int64
#
# Number of duplicate rows:
# 0

# %% [markdown]
# ## Análisis de variables univariadas
#
# ### Subtask:
# Explorar la distribución de cada columna individualmente, usando estadísticas descriptivas y visualizaciones (histogramas, diagramas de caja, etc.).

# %% [markdown]
# **Reasoning**:
# Generate descriptive statistics for the numerical and categorical columns and create histograms for numerical columns and a count plot for the categorical column to explore their distributions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Generate descriptive statistics for numerical columns
print("Descriptive statistics for numerical columns:")
display(df[['peso', 'altura', 'imc']].describe())

# 2. Generate descriptive statistics for categorical columns
print("\nDescriptive statistics for categorical columns:")
display(df[['nombre', 'categoría']].describe(include='object'))

# 3. Create a histogram for the 'peso' column
plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
sns.histplot(df['peso'], kde=True)
plt.xlabel('Peso')
plt.ylabel('Frecuencia')
plt.title('Distribución de Peso')

# 4. Create a histogram for the 'altura' column
plt.subplot(1, 3, 2)
sns.histplot(df['altura'], kde=True)
plt.xlabel('Altura')
plt.ylabel('Frecuencia')
plt.title('Distribución de Altura')

# 5. Create a histogram for the 'imc' column
plt.subplot(1, 3, 3)
sns.histplot(df['imc'], kde=True)
plt.xlabel('IMC')
plt.ylabel('Frecuencia')
plt.title('Distribución de IMC')

plt.tight_layout()
plt.show()

# 6. Create a count plot for the 'categoría' column
plt.figure(figsize=(8, 5))
sns.countplot(x='categoría', data=df)
plt.xlabel('Categoría')
plt.ylabel('Conteo')
plt.title('Distribución de Categorías de IMC')
plt.show()
# Out:
# Descriptive statistics for numerical columns:
#              peso      altura         imc
# count  100.000000  100.000000  100.000000
# mean    68.010000    1.697277   24.185216
# std     16.216026    0.168253    7.296660
# min     40.000000    1.414389   10.622137
# 25%     55.750000    1.539470   19.244213
# 50%     66.000000    1.682558   23.370064
# 75%     81.000000    1.846799   28.055877
# max     99.000000    1.982977   47.005363
# Descriptive statistics for categorical columns:
#           nombre    categoría
# count        100          100
# unique        60            3
# top     Fernando  peso normal
# freq           5           40

# %% [markdown]
# ## Análisis de variables bivariadas y multivariadas
#
# ### Subtask:
# Investigar las relaciones entre pares de variables o múltiples variables utilizando visualizaciones (diagramas de dispersión, gráficos de barras agrupadas, mapas de calor, etc.) y medidas estadísticas (correlación, tablas de contingencia).

# %% [markdown]
# **Reasoning**:
# Calculate and display the correlation matrix for the numerical columns and visualize it with a heatmap.

# %%
# 1. Calculate the correlation matrix for the numerical columns
numerical_cols = ['peso', 'altura', 'imc']
correlation_matrix = df[numerical_cols].corr()

# Display the correlation matrix
print("Correlation Matrix:")
display(correlation_matrix)

# 2. Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap de Correlación entre Peso, Altura, e IMC')
plt.show()
# Out:
# Correlation Matrix:
#             peso    altura       imc
# peso    1.000000  0.121224  0.725681
# altura  0.121224  1.000000 -0.571834
# imc     0.725681 -0.571834  1.000000

# %% [markdown]
# **Reasoning**:
# Create scatter plots to visualize the relationships between pairs of numerical variables as requested in the instructions.

# %%
# 3. Create a scatter plot to visualize the relationship between 'peso' and 'altura'
plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
sns.scatterplot(x='peso', y='altura', data=df)
plt.xlabel('Peso')
plt.ylabel('Altura')
plt.title('Relación entre Peso y Altura')

# 4. Create a scatter plot to visualize the relationship between 'peso' and 'imc'
plt.subplot(1, 3, 2)
sns.scatterplot(x='peso', y='imc', data=df)
plt.xlabel('Peso')
plt.ylabel('IMC')
plt.title('Relación entre Peso e IMC')

# 5. Create a scatter plot to visualize the relationship between 'altura' and 'imc'
plt.subplot(1, 3, 3)
sns.scatterplot(x='altura', y='imc', data=df)
plt.xlabel('Altura')
plt.ylabel('IMC')
plt.title('Relación entre Altura e IMC')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Create box plots to visualize the relationship between the categorical variable 'categoría' and the numerical variables 'peso', 'altura', and 'imc' as requested in the instructions.

# %%
# 6. Create a box plot to visualize the relationship between 'categoría' and 'peso'
plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
sns.boxplot(x='categoría', y='peso', data=df)
plt.xlabel('Categoría de IMC')
plt.ylabel('Peso')
plt.title('Peso por Categoría de IMC')

# 7. Create a box plot to visualize the relationship between 'categoría' and 'altura'
plt.subplot(1, 3, 2)
sns.boxplot(x='categoría', y='altura', data=df)
plt.xlabel('Categoría de IMC')
plt.ylabel('Altura')
plt.title('Altura por Categoría de IMC')

# 8. Create a box plot to visualize the relationship between 'categoría' and 'imc'
plt.subplot(1, 3, 3)
sns.boxplot(x='categoría', y='imc', data=df)
plt.xlabel('Categoría de IMC')
plt.ylabel('IMC')
plt.title('IMC por Categoría de IMC')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Create a count plot of 'categoría' to explore the distribution of categories. Visualizing by 'nombre' is not practical due to the large number of unique names.

# %%
# 9. Create a count plot of 'categoría'
plt.figure(figsize=(8, 5))
sns.countplot(x='categoría', data=df)
plt.xlabel('Categoría de IMC')
plt.ylabel('Conteo')
plt.title('Distribución de Categorías de IMC')
plt.show()

# %% [markdown]
# ## Identificación de valores atípicos (outliers)
#
# ### Subtask:
# Detectar y analizar valores que se desvían significativamente del resto de los datos.

# %% [markdown]
# **Reasoning**:
# Create box plots for 'peso', 'altura', and 'imc' to visually identify potential outliers and use the IQR method to identify outliers programmatically. Then, display the rows identified as outliers for each column.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. Create a box plot for the 'peso' column
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
sns.boxplot(y=df['peso'])
plt.title('Box Plot de Peso')
plt.ylabel('Peso')

# 2. Create a box plot for the 'altura' column
plt.subplot(1, 3, 2)
sns.boxplot(y=df['altura'])
plt.title('Box Plot de Altura')
plt.ylabel('Altura')

# 3. Create a box plot for the 'imc' column
plt.subplot(1, 3, 3)
sns.boxplot(y=df['imc'])
plt.title('Box Plot de IMC')
plt.ylabel('IMC')

plt.tight_layout()
plt.show()

# 4. Use the Interquartile Range (IQR) method to programmatically identify outliers
numerical_cols = ['peso', 'altura', 'imc']
outlier_indices = {}

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outlier_indices[col] = outliers.index

    print(f"\n--- Outliers for '{col}' (IQR Method) ---")
    print(f"  Q1: {Q1:.2f}")
    print(f"  Q3: {Q3:.2f}")
    print(f"  IQR: {IQR:.2f}")
    print(f"  Lower Bound: {lower_bound:.2f}")
    print(f"  Upper Bound: {upper_bound:.2f}")
    print(f"  Number of outliers: {len(outliers)}")

    # 5. Display the rows identified as outliers
    display(outliers)
# Out:
# --- Outliers for 'peso' (IQR Method) ---
#   Q1: 55.75
#   Q3: 81.00
#   IQR: 25.25
#   Lower Bound: 17.88
#   Upper Bound: 118.88
#   Number of outliers: 0
# Empty DataFrame
# Columns: [nombre, peso, altura, imc, categoría]
# Index: []
# --- Outliers for 'altura' (IQR Method) ---
#   Q1: 1.54
#   Q3: 1.85
#   IQR: 0.31
#   Lower Bound: 1.08
#   Upper Bound: 2.31
#   Number of outliers: 0
# Empty DataFrame
# Columns: [nombre, peso, altura, imc, categoría]
# Index: []
# --- Outliers for 'imc' (IQR Method) ---
#   Q1: 19.24
#   Q3: 28.06
#   IQR: 8.81
#   Lower Bound: 6.03
#   Upper Bound: 41.27
#   Number of outliers: 5
#     nombre  peso    altura        imc  categoría
# 10  Daniel    94  1.477311  43.070901  sobrepeso
# 12     Ana    98  1.443907  47.005363  sobrepeso
# 29   Julia    91  1.471026  42.053359  sobrepeso
# 68     Eva    95  1.483215  43.183260  sobrepeso
# 95  Julian    91  1.426925  44.692927  sobrepeso

# %% [markdown]
# ## Ingeniería de características (feature engineering)
#
# ### Subtask:
# Crear nuevas características a partir de las existentes que puedan ser más útiles para el análisis o modelado.

# %% [markdown]
# **Reasoning**:
# Create new features based on existing ones and display the updated DataFrame.

# %%
# Create a new feature: inverse of IMC
df['inverse_imc'] = 1 / df['imc']

# Create a new feature: a ratio of weight to height (different from IMC)
df['peso_altura_ratio'] = df['peso'] / df['altura']

# Display the updated DataFrame with new features
display(df.head())
# Out:
#       nombre  peso  altura        imc     categoría  inverse_imc  \
# 0  Alexander    49    1.78  15.465219  bajo de peso     0.064661
# 1  Alejandra    57    1.60  22.265625   peso normal     0.044912
# 2      Dario    64    1.64  23.795360   peso normal     0.042025
# 3     Wilson    80    1.71  27.358845     sobrepeso     0.036551
# 4     Camila    55    1.50  24.444444   peso normal     0.040909
#
#    peso_altura_ratio
# 0          27.528090
# 1          35.625000
# 2          39.024390
# 3          46.783626
# 4          36.666667

# %% [markdown]
# ## Resumen de hallazgos
#
# ### Subtask:
# Recopilar los hallazgos clave del EDA y documentarlos para futuras referencias.

# %% [markdown]
# **Reasoning**:
# Synthesize the key findings from the previous EDA steps and document them in a summary.

# %%
eda_summary = """
Summary of Exploratory Data Analysis (EDA)

1.  Initial Data Loading and Understanding:
    - The dataset consists of 100 entries and 5 columns: 'nombre', 'peso', 'altura', 'imc', and 'categoría'.
    - Data types are appropriate: numerical for 'peso', 'altura', and 'imc', and object for 'nombre' and 'categoría'.
    - No missing values were found in the initial dataset.

2.  Data Cleaning:
    - Checked for missing values and found none across all columns.
    - Checked for duplicate rows and found none.
    - The dataset is clean in terms of missing values and duplicates.

3.  Univariate Analysis:
    - Numerical columns ('peso', 'altura', 'imc'):
        - 'peso' and 'altura' show distributions that are approximately normal, with means around 68 kg and 1.70 m respectively.
        - 'imc' distribution is slightly right-skewed, with a mean around 24.19.
    - Categorical column ('categoría'):
        - The most frequent category is 'peso normal', followed by 'sobrepeso' and 'bajo de peso'.

4.  Bivariate and Multivariate Analysis:
    - Correlation Analysis:
        - 'peso' and 'imc' have a strong positive correlation (0.73).
        - 'altura' and 'imc' have a moderate negative correlation (-0.57).
        - 'peso' and 'altura' have a weak positive correlation (0.12).
    - Relationships with 'categoría':
        - 'peso' and 'imc' show clear distinctions across 'categoría', with higher values in 'sobrepeso' and lower values in 'bajo de peso'.
        - 'altura' shows less variation across 'categoría'.

5.  Outlier Identification:
    - Using the IQR method, 5 outliers were identified in the 'imc' column, all of which were above the upper bound (41.27). No outliers were detected in 'peso' or 'altura' using this method.

6.  Feature Engineering:
    - Two new features were created:
        - 'inverse_imc': The inverse of 'imc' (1 / imc), which might be useful if modeling requires a different relationship with IMC.
        - 'peso_altura_ratio': The ratio of 'peso' to 'altura' (peso / altura), providing an alternative measure of body proportion.

Key Insights for Future Analysis:
- The 'imc' column is derived from 'peso' and 'altura' and is strongly correlated with both.
- The 'categoría' column is directly derived from 'imc' and shows distinct distributions for 'peso' and 'imc'.
- Outliers exist in the 'imc' column and may need to be addressed depending on the requirements of future analysis or modeling.
- The newly created features 'inverse_imc' and 'peso_altura_ratio' offer alternative perspectives on body composition and could be explored in modeling.
"""

print(eda_summary)
# Out:
# Summary of Exploratory Data Analysis (EDA)
#
# 1.  Initial Data Loading and Understanding:
#     - The dataset consists of 100 entries and 5 columns: 'nombre', 'peso', 'altura', 'imc', and 'categoría'.
#     - Data types are appropriate: numerical for 'peso', 'altura', and 'imc', and object for 'nombre' and 'categoría'.
#     - No missing values were found in the initial dataset.
#
# 2.  Data Cleaning:
#     - Checked for missing values and found none across all columns.
#     - Checked for duplicate rows and found none.
#     - The dataset is clean in terms of missing values and duplicates.
#
# 3.  Univariate Analysis:
#     - Numerical columns ('peso', 'altura', 'imc'):
#         - 'peso' and 'altura' show distributions that are approximately normal, with means around 68 kg and 1.70 m respectively.
#         - 'imc' distribution is slightly right-skewed, with a mean around 24.19.
#     - Categorical column ('categoría'):
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 100 entries and 5 columns: 'nombre', 'peso', 'altura', 'imc', and 'categoría'.
# *   There were no missing values or duplicate rows found in the dataset.
# *   Numerical columns ('peso', 'altura', 'imc') showed generally normal or slightly skewed distributions.
# *   The 'categoría' column shows 'peso normal' as the most frequent category.
# *   'peso' and 'imc' have a strong positive correlation (0.73), while 'altura' and 'imc' have a moderate negative correlation (-0.57).
# *   The 'categoría' column shows clear distinctions in 'peso' and 'imc' distributions.
# *   5 outliers were identified in the 'imc' column using the IQR method, all above the upper bound.
# *   Two new features, 'inverse\_imc' and 'peso\_altura\_ratio', were created.
#
# ### Insights or Next Steps
#
# *   The strong correlations and the relationship between 'imc' and 'categoría' indicate that 'imc' is a key variable for understanding body composition in this dataset.
# *   Further investigation into the 5 identified outliers in the 'imc' column may be necessary depending on the goals of subsequent analysis or modeling.
